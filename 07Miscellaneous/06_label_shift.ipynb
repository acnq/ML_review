# %%
import torch
import gpytorch
from autogluon.tabular import TabularPredictor

# %% [markdown]
# ## Label Shift

# %%
wp = torch.rand(100) * 2 - 1
wq = torch.rand(100) * 2 - 1

p = torch.randn(100)
q = torch.randn(100) * 4.0 + 0.4
x = torch.arange(-3, 3, 0.01)
k = gpytorch.kernels.RBFKernel()
f = k(x, p) @ wp - k(x, q) @ wq
