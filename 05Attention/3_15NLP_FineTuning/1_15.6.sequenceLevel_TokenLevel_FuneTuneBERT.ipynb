# %% [markdown]
# ## 15.6. Fine-Tuning BERT for Sequence-level and Token-level Applications

# %% [markdown]
# ### 15.6.1. Single Text Classification

# %% [markdown]
# ### 15.6.2. Text-Text Classification or Regression

# %% [markdown]
# #### 15.6.3. Text Tagging

# %% [markdown]
# #### 15.6.4. Question-Answer (QA)
