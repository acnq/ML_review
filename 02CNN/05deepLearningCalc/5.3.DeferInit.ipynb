# %% [markdown]
# ### 5.3 Defers Initialization

# %% [markdown]
# ### 5.3.1 Instantialization of Network

# %%
import torch
from torch import nn
from d2l import torch as d2l

net = nn.Sequential(nn.LazyLinear(256), nn.ReLU(), nn.LazyLinear(10))
net[0].weight

# %%
X = torch.rand(2, 20)
net(X)

net[0].weight.shape
# Out:
# torch.Size([256, 20])
