# %% [markdown]
# ## 12.4 Hardwares

# %% [markdown]
# ### 12.4.1 Computers

# %% [markdown]
# ### 12.4.2 Memory

# %% [markdown]
# ### 12.4.3 Storage Devices
#
# #### 12.4.3.1 Hard Disk Drives: HDD
# #### 12.4.3.2 Solid State Drives: SSD
# #### 12.4.3.3 Cloud Storage

# %% [markdown]
# ### 12.4.4 Central Processing Unit: CPU
#
# #### 12.4.4.1 Microprocess Architecture
# #### 12.4.4.2 Vectorization
# #### 12.4.4.3 Cache

# %% [markdown]
# ### 12.4.5 CPU and Other Accelerating Disk

# %% [markdown]
# ### 12.4.6 Network and Bus

# %% [markdown]
# ### 12.4.7 More Latency
