# %% [markdown]
# ## 12.7. Parameter Server

# %% [markdown]
# ### 12.7.1 Data Parallelized Trainning

# %% [markdown]
# ### 12.7.2 Ring Synchronization

# %% [markdown]
# ### 12.7.3 Multi-Machine Training

# %% [markdown]
# ### 12.7.4 Key-Value Storage

# %% [markdown]
# $$
# \textbf{g}_i = \sum_{k∈\text{workers}}\sum_{j∈\text{GPUs}} \textbf{g}_{ijk}
# $$
