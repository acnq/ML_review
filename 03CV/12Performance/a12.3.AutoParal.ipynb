# %% [markdown]
# ## 12.3*. Auto Parallelization
#
# need at least 2 GPU

# %%
import torch
from d2l import torch as d2l

# %% [markdown]
# ### 12.3.1 GPU-based Parallelizaiton

# %%
devices = d2l.try_all_gpus()
def run(x):
  return [x.mm(x) for _ in range(50)]

x_gpu1 = torch.rand(size=(4000, 4000), device=devices[0])

# %% [markdown]
# ### 12.3.2 Parallelization and Communication

# %%
def copy_to_cpu(x, non_blocking=False):
  return [y.to('cpu', non_blocking=non_blocking) for y in x]

with d2l.Benchmark('在GPU上运行'):
  y = run(x_gpu1)
  torch.cuda.synchronize()
  
with d2l.Benchmark('复制到cpu'):
  y_cpu = copy_to_cpu(y)
  torch.cuda.synchronize()
# Out:
# 在GPU上运行: 4.8879 sec
# 复制到cpu: 4.0570 sec

# %%
with d2l.Benchmark('在GPU1上运行并复制到CPU'):
  y = run(x_gpu1)
  y_cpu = copy_to_cpu(y, True)
  torch.cuda.synchronize()
# Out:
# 在GPU1上运行并复制到CPU: 35.7206 sec
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 3
#       1 with d2l.Benchmark('在GPU1上运行并复制到CPU'):
#       2   y = run(x_gpu1)
# ----> 3   y_cpu = copy_to_cpu(y, True)
#       4   torch.cuda.synchronize()
#
# Cell In[3], line 2, in copy_to_cpu(x, non_blocking)
#       1 def copy_to_cpu(x, non_blocking=False):
# ----> 2   return [y.to('cpu', non_blocking=non_blocking) for y in x]
#
# Cell In[3], line 2, in <listcomp>(.0)
#       1 def copy_to_cpu(x, non_blocking=False):
# ----> 2   return [y.to('cpu', non_blocking=non_blocking) for y in x]
#
# RuntimeError: CUDA error: out of memory
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
