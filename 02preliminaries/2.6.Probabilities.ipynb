# %% [markdown]
# ## 2.6. Probabilities

# %% [markdown]
# ### 2.6.1 Basics in Probabilities

# %%
# %matplotlib inline
import torch

from torch.distributions import multinomial
from d2l import torch as d2l

# %%
fair_probs = torch.ones([6]) / 6
multinomial.Multinomial(1, fair_probs).sample()
# Out:
# tensor([0., 0., 0., 0., 1., 0.])

# %%
multinomial.Multinomial(10, fair_probs).sample()
# Out:
# tensor([1., 2., 2., 0., 3., 2.])

# %%
# 将结果存储为32位浮点数以进行除法
counts = multinomial.Multinomial(1000, fair_probs).sample()
counts / 1000 # 相对频率作为估计值
# Out:
# tensor([0.1730, 0.1820, 0.1660, 0.1640, 0.1520, 0.1630])

# %%
counts = multinomial.Multinomial(10, fair_probs).sample((500,))
print(counts.shape)
print(counts)
cum_counts = counts.cumsum(dim=0)
print(cum_counts.shape)
print(cum_counts)
estimates = cum_counts / cum_counts.sum(dim=1, keepdims=True)
print(estimates.shape)
print(estimates)
# Out:
# torch.Size([500, 6])
# tensor([[3., 3., 1., 0., 3., 0.],
#         [3., 1., 0., 2., 0., 4.],
#         [1., 1., 4., 2., 1., 1.],
#         ...,
#         [2., 0., 3., 0., 3., 2.],
#         [4., 2., 1., 1., 1., 1.],
#         [3., 2., 0., 3., 2., 0.]])
# torch.Size([500, 6])
# tensor([[  3.,   3.,   1.,   0.,   3.,   0.],
#         [  6.,   4.,   1.,   2.,   3.,   4.],
#         [  7.,   5.,   5.,   4.,   4.,   5.],
#         ...,
#         [849., 839., 839., 781., 805., 867.],
#         [853., 841., 840., 782., 806., 868.],
#         [856., 843., 840., 785., 808., 868.]])
# torch.Size([500, 6])
# tensor([[0.3000, 0.3000, 0.1000, 0.0000, 0.3000, 0.0000],
#         [0.3000, 0.2000, 0.0500, 0.1000, 0.1500, 0.2000],
#         [0.2333, 0.1667, 0.1667, 0.1333, 0.1333, 0.1667],
#         ...,
#         [0.1705, 0.1685, 0.1685, 0.1568, 0.1616, 0.1741],
#         [0.1709, 0.1685, 0.1683, 0.1567, 0.1615, 0.1739],
#         [0.1712, 0.1686, 0.1680, 0.1570, 0.1616, 0.1736]])

# %%
d2l.set_figsize((6, 4.5))
for i in range(6):
  d2l.plt.plot(estimates[:, i].numpy(), label=("P(die=" + str(i + 1) + ")"))
d2l.plt.axhline(y=0.167, color='black', linestyle='dashed')
d2l.plt.gca().set_xlabel('Groups of expreiments')
d2l.plt.gca().set_ylabel('Estimated probability')
d2l.plt.legend();

# %% [markdown]
# #### 2.6.1.1 Probability Theory Axioms

# %% [markdown]
# #### 2.6.1.2 Random Variables

# %% [markdown]
# ### 2.6.2 Multiple Random Variablees

# %% [markdown]
# #### 2.6.2.1 Joint Probabilites

# %% [markdown]
# #### 2.6.2.2 Conditional Probabilities

# %% [markdown]
# #### 2.6.2.3 Bayes' Theorem

# %% [markdown]
# #### 2.6.2.4 Marginalization

# %% [markdown]
# #### 2.6.2.5 Independence

# %% [markdown]
# #### 2.6.2.6 Application

# %% [markdown]
# ### 2.6.3 Expectation and Variance
